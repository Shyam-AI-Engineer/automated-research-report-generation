# %%
print("ok")
# Out:
# ok

# %%
import sys, os

# %%
# Get project root — one level up from 'research_and_analyst'
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

print("Project root added to path:", project_root)
# Out:
# Project root added to path: d:\GITHUB Projects\automated-research-report-generation

# %%
from research_and_analyst.utils.config_loader import load_config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from research_and_analyst.utils.config_loader import load_config
#
# File d:\GITHUB Projects\automated-research-report-generation\research_and_analyst\utils\config_loader.py:5
#       3 import json
#       4 from pathlib import Path
# ----> 5 from logger import GLOBAL_LOGGER as log
#       6 from exception.custom_exception import ResearchAnalystException
#       9 def _project_root() -> Path:
#
# ModuleNotFoundError: No module named 'logger'
